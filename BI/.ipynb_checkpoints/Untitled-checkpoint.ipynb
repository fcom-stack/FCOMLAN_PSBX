# %% [raw]
# import json
# # load data using Python JSON module
# with open('StreamingHistory.json','r') as f:
#     data = json.loads(f.read())
#
# # Normalizing data
# df = pd.json_normalize(data)

# %% [raw]
# A list of items (e.g. songs, videos, and podcasts) listened to or watched in the past year, including:
#
# Date and time of when the stream ended in UTC format (Coordinated Universal Time zone).
# Name of "creator" for each stream (e.g. the artist name if a music track).
# Name of items listened to or watched (e.g. title of music track or name of video).
# “msPlayed”- Stands for how many mili-seconds the track was listened to.

# %%
pip install ipywidgets

# %%
pip install bar_chart_race

# %% [markdown]
# ## PERSONAL SPOTIFY DATA

# %%
import pandas as pd
import json
import datetime
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import time 
from functools import reduce
from datetime import timedelta
import plotly.express as px
from wordcloud import WordCloud 
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
import seaborn as sns

# %%
def load_myspotify_data():
    data = pd.read_json('data/StreamingHistory.json')
    lowercase = lambda x: str(x).lower()
    data.rename(lowercase, axis='columns', inplace=True)
    data['endtime'] = pd.to_datetime(data['endtime'])
    data['duration'] = pd.to_timedelta(data['msplayed'], 'ms')
    data['minplayed'] = data['msplayed'] / 1000 / 60
    data['starttime'] = data['endtime'] - data['duration']
    data['date'] = data['starttime'].dt.date
    data['year'] = data['starttime'].dt.year
    data['month'] = data['starttime'].dt.month
    data['week'] = data['starttime'].dt.isocalendar().week
    data['dayofweek'] = data['starttime'].dt.dayofweek
    data['day'] = data['starttime'].dt.day
    data['hour'] = data['starttime'].dt.hour
    data['minute'] = data['starttime'].dt.minute
    data['quarter'] = data['starttime'].dt.quarter
    return data

# %%
def extract_myartist(df):
    my_artist = list(set(df.artistname))
    my_artist.remove("")
    return pd.DataFrame(my_artist)

# %%
def extract_mytrack(df):
    my_track = list(set(df.trackname))
    my_track.remove("")
    return pd.DataFrame(my_track)

# %%
def get_quarter(df,quarter):
    if quarter == 'Q1':
        return df[df.quarter == 1] 
    elif quarter == 'Q2':
        return df[df.quarter == 2] 
    elif quarter == 'Q3':
        return df[df.quarter == 3]    
    elif quarter == 'Q4':
        return df[df.quarter == 4]
    else :
        return df

# %%
def get_total_duration_by_(df,column):
    new_df = df.groupby(column).sum()['minplayed'].reset_index()
    return new_df

# %%
def get_moy_duration_by_(df,column):
    new_df = df.groupby(column).mean()['minplayed'].reset_index().sort_values('minplayed', ascending=False).rename(columns={'minplayed': 'amount'})
    return new_df

# %%
def get_tracks_by_date(df,date):
    new_df = df[df.date == date]
    return new_df[['trackname','artistname','minplayed']]

# %%
def get_top10_by_(df,group,column):
    if group =='':
         return df.groupby(column).agg({'minplayed':'sum','msplayed' : 'count'}).reset_index().sort_values(['minplayed','msplayed'], ascending=False).rename(columns={'minplayed': 'duration_min','msplayed':'total_count'}).head(10)    
                    
    else :    
        subgroup = df[group].drop_duplicates()
        new_df = subgroup.apply(lambda var : df[df[group] == var].groupby(column).agg({'minplayed':'sum','msplayed' : 'count'}).reset_index().sort_values(['minplayed','msplayed'], ascending=False).rename(columns={'minplayed': 'duration_min','msplayed':'total_count'}).head(10))    
        return reduce(lambda df1,df2 : df1.append(df2), new_df).sort_values([group,'duration_min'], ascending=(True,False))

# %%
def get_list_features_by_track(df,features):
    return df.merge(features, how='left', on='trackname')

# %% [markdown]
# ## SPOTIFY API

# %%
client_id = 'ef0d92753d4e44658a3a28ce21de6845'
client_secret = '828972dcf8b84b9f8fe76e27cd570c6d'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def get_features(artist,track):  
    
    columns = ["artistname","followers","genres","popularity","artistType",
               "trackname","danceability","energy","loudness","speechiness","instrumentalness",
              "liveness","valence","tempo","duration_ms"]
    
    df = pd.DataFrame([[artist,"","","","",track,"","","","","","","","",""]],columns = columns )
    
    results = sp.search(q='artist:' + artist, type='artist')
    items = results['artists']['items']
    
    if len(items) > 0:
        #get artist features
        features = items[0]
        df.followers[0] = features['followers']['total']
        df.genres[0] = features['genres']
        df.popularity[0] = features['popularity']
        df.artistType[0] = features['type'] 
    
    results = sp.search(q='artist:'+artist+' track:'+track,type='track')
    items = results['tracks']['items']   
    
    if len(items) > 0:
        features = sp.audio_features(items[0]['id'])[0]
        if(features is not None):
            df.danceability[0] = features['danceability']
            df.energy[0] = features['energy']
            df.loudness[0] = features['loudness']
            df.speechiness[0] = features['speechiness']
            df.instrumentalness[0] = features['instrumentalness']
            df.liveness[0] = features['liveness']
            df.valence[0] = features['valence']
            df.tempo[0] = features['tempo']
            df.duration_ms[0] = features['duration_ms']                

    return df

# %%
def create_features_df(df): 
    data = df.drop_duplicates(subset=['artistname', 'trackname'], keep="first")
    inter_df = data.apply(lambda row : get_features(row.artistname, row.trackname),axis=1)
    return reduce(lambda df1,df2 : df1.append(df2), inter_df)

# %%
def get_list_genres(df) :
    liste = df.genres.apply(pd.Series).reset_index().melt(id_vars='index').dropna()[['index', 'value']]
    return liste

# %%
def get_list_genres(df) :
    print(df[df.genres == '0'])
    series = df[df.genres != 0].genres.apply(eval)  
    
    new = pd.Series([x for _list in series for x in _list])
    return new

# %%
get_list_genres(features).values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-247-a2c90febb3b5> in <module>
# ----> 1 get_list_genres(features).values
#
# <ipython-input-246-62408c07d7da> in get_list_genres(df)
#       1 def get_list_genres(df) :
# ----> 2     print(df[df.genres != '0'].genres.apply(eval))
#       3     series = df[df.genres != 0].genres.apply(eval)
#       4
#       5     new = pd.Series([x for _list in series for x in _list])
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
series = get_list_genres(features)
type(series)
# Out:
# pandas.core.series.Series

# %%
def clean_alt_list(list_):
    list_ = df.replace('[', '"[')
    list_ = list_.replace(']', ']"')
    return list_

# %%
series = features.genres.apply(clean_alt_list)

# %%
series
# Out:
# 0       ["'francoton'","'french hip hop'","'french pop...
# 1                       ["'azontobeats'","'pop urbaine'"]
# 2                         ["'francoton'","'pop urbaine'"]
# 3                         ["'francoton'","'zouk riddim'"]
# 4       ["'afro dancehall'","'dancehall'","'nigerian h...
#                               ...
# 2051                 ["'french hip hop'","'pop urbaine'"]
# 2052                 ["'french hip hop'","'pop urbaine'"]
# 2053                 ["'french hip hop'","'pop urbaine'"]
# 2054                 ["'french hip hop'","'pop urbaine'"]
# 2055                 ["'french hip hop'","'pop urbaine'"]
# Name: genres, Length: 2056, dtype: object

# %%
def to_1D(series):
    return pd.Series([x for _list in series for x in _list]).value_counts()

# %%
to_1D(features.genres)
# Out:
# '    13471
#      10516
# o     7404
# p     7376
# a     6980
# n     5825
# r     5589
# ,     4850
# i     4511
# e     4251
# c     3696
# h     3463
# t     2642
# s     2359
# l     2118
# [     2001
# ]     2001
# f     1887
# u     1570
# b     1366
# d     1257
# m      953
# g      906
# k      557
# w      430
# z      335
# y      193
# v      178
# &      131
# -      103
# 0       55
# q       49
# j       24
# x       14
# +        4
# "        2
# dtype: int64

# %%
def to_1D(series):
    return pd.Series([_list for _list in series])

# %%
to_1D(series)
# Out:
# 0       [francoton, french hip hop, french pop, rap co...
# 1                              [azontobeats, pop urbaine]
# 2                                [francoton, pop urbaine]
# 3                                [francoton, zouk riddim]
# 4       [afro dancehall, dancehall, nigerian hip hop, ...
#                               ...
# 2051                        [french hip hop, pop urbaine]
# 2052                        [french hip hop, pop urbaine]
# 2053                        [french hip hop, pop urbaine]
# 2054                        [french hip hop, pop urbaine]
# 2055                        [french hip hop, pop urbaine]
# Length: 2056, dtype: object

# %%
def get_moy_features (df):
    cols = ["popularity","danceability","energy","loudness","speechiness","instrumentalness",
              "liveness","valence","tempo"]
    return df[cols].mean()*100

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# ## Personal data

# %%
my_data = load_myspotify_data()
my_data
# Out:
#                  endtime        artistname              trackname  msplayed  \
# 0    2020-12-30 10:54:00                ND                  Rodeo     64833
# 1    2021-01-03 11:45:00             Ninho      La vie qu'on mène    281216
# 2    2021-01-03 11:51:00             Ninho      La vie qu'on mène    307861
# 3    2021-01-03 22:02:00               Jul                 Tel Me     10666
# 4    2021-01-03 22:03:00  Hillsong Worship  What A Beautiful Name      3306
# ...                  ...               ...                    ...       ...
# 6998 2022-01-03 23:49:00          Singuila         Elle me saoûle     19647
# 6999 2022-01-03 23:50:00          Singuila         Elle me saoûle    103978
# 7000 2022-01-03 23:55:00          Singuila  La femme de quelqu'un    262452
# 7001 2022-01-03 23:55:00          Singuila  L'amour ne suffit pas      2358
# 7002 2022-01-03 23:59:00          Singuila  La femme de quelqu'un    262452
#
#                    duration  minplayed               starttime        date  \
# 0    0 days 00:01:04.833000   1.080550 2020-12-30 10:52:55.167  2020-12-30
# 1    0 days 00:04:41.216000   4.686933 2021-01-03 11:40:18.784  2021-01-03
# 2    0 days 00:05:07.861000   5.131017 2021-01-03 11:45:52.139  2021-01-03
# 3    0 days 00:00:10.666000   0.177767 2021-01-03 22:01:49.334  2021-01-03
# 4    0 days 00:00:03.306000   0.055100 2021-01-03 22:02:56.694  2021-01-03
# ...                     ...        ...                     ...         ...
# 6998 0 days 00:00:19.647000   0.327450 2022-01-03 23:48:40.353  2022-01-03
# 6999 0 days 00:01:43.978000   1.732967 2022-01-03 23:48:16.022  2022-01-03
# 7000 0 days 00:04:22.452000   4.374200 2022-01-03 23:50:37.548  2022-01-03
# 7001 0 days 00:00:02.358000   0.039300 2022-01-03 23:54:57.642  2022-01-03
# 7002 0 days 00:04:22.452000   4.374200 2022-01-03 23:54:37.548  2022-01-03
#
#       year  month  week  dayofweek  day  hour  minute  quarter
# 0     2020     12    53          2   30    10      52        4
# 1     2021      1    53          6    3    11      40        1
# 2     2021      1    53          6    3    11      45        1
# 3     2021      1    53          6    3    22       1        1
# 4     2021      1    53          6    3    22       2        1
# ...    ...    ...   ...        ...  ...   ...     ...      ...
# 6998  2022      1     1          0    3    23      48        1
# 6999  2022      1     1          0    3    23      48        1
# 7000  2022      1     1          0    3    23      50        1
# 7001  2022      1     1          0    3    23      54        1
# 7002  2022      1     1          0    3    23      54        1
#
# [7003 rows x 16 columns]

# %%
my_data.describe()
# Out:
#            msplayed                   duration    minplayed         year  \
# count  7.003000e+03                       7003  7003.000000  7003.000000
# mean   1.552330e+05  0 days 00:02:35.233006711     2.587217  2021.005997
# std    1.799767e+05  0 days 00:02:59.976687449     2.999611     0.079044
# min    0.000000e+00            0 days 00:00:00     0.000000  2020.000000
# 25%    4.904500e+04     0 days 00:00:49.045000     0.817417  2021.000000
# 50%    1.745790e+05     0 days 00:02:54.579000     2.909650  2021.000000
# 75%    2.046290e+05     0 days 00:03:24.629000     3.410483  2021.000000
# max    5.290736e+06     0 days 01:28:10.736000    88.178933  2022.000000
#
#              month         week    dayofweek          day         hour  \
# count  7003.000000  7003.000000  7003.000000  7003.000000  7003.000000
# mean      6.730830    27.063259     3.249179    15.185920    13.604884
# std       3.764178    16.333775     1.873544     9.373231     5.507671
# min       1.000000     1.000000     0.000000     1.000000     0.000000
# 25%       3.000000    10.000000     2.000000     5.000000    10.000000
# 50%       7.000000    30.000000     3.000000    16.000000    15.000000
# 75%      10.000000    43.000000     5.000000    24.000000    18.000000
# max      12.000000    53.000000     6.000000    31.000000    23.000000
#
#             minute      quarter
# count  7003.000000  7003.000000
# mean     29.304727     2.555333
# std      17.290632     1.225229
# min       0.000000     1.000000
# 25%      14.000000     1.000000
# 50%      30.000000     3.000000
# 75%      44.000000     4.000000
# max      59.000000     4.000000

# %%
#Total number of songs

len(my_data)
# Out:
# 7003

# %%
# Number of gathered songs

my_data['trackname'].nunique()
# Out:
# 2057

# %%
# Number of gathered artist
my_data['artistname'].nunique()
# Out:
# 858

# %%
get_quarter(my_data,'Q1')
# Out:
#                  endtime              artistname                 trackname  \
# 339  2021-01-02 18:28:00                 Rudeboy            Reason With Me
# 340  2021-01-02 18:28:00                   Ninho        Lettre à une femme
# 341  2021-01-02 18:29:00                 Rudeboy            Reason With Me
# 342  2021-01-02 18:29:00                   Ninho        Lettre à une femme
# 343  2021-01-02 18:29:00                   Ninho        Lettre à une femme
# ...                  ...                     ...                       ...
# 2443 2021-03-31 14:34:00                  WizKid  Ginger (feat. Burna Boy)
# 2444 2021-03-31 14:34:00                    Rema                 Ginger Me
# 2445 2021-03-31 14:35:00                Omah Lay                     Lo Lo
# 2446 2021-03-31 14:37:00                Omah Lay                     Godly
# 2447 2021-03-31 14:38:00  Sly & The Family Stone        Dance to the Music
#
#       msplayed               duration  minplayed               starttime  \
# 339      30079 0 days 00:00:30.079000   0.501317 2021-01-02 18:27:29.921
# 340        576 0 days 00:00:00.576000   0.009600 2021-01-02 18:27:59.424
# 341       6575 0 days 00:00:06.575000   0.109583 2021-01-02 18:28:53.425
# 342       1489 0 days 00:00:01.489000   0.024817 2021-01-02 18:28:58.511
# 343        190 0 days 00:00:00.190000   0.003167 2021-01-02 18:28:59.810
# ...        ...                    ...        ...                     ...
# 2443      5503 0 days 00:00:05.503000   0.091717 2021-03-31 14:33:54.497
# 2444     18730 0 days 00:00:18.730000   0.312167 2021-03-31 14:33:41.270
# 2445     18325 0 days 00:00:18.325000   0.305417 2021-03-31 14:34:41.675
# 2446    175215 0 days 00:02:55.215000   2.920250 2021-03-31 14:34:04.785
# 2447     13916 0 days 00:00:13.916000   0.231933 2021-03-31 14:37:46.084
#
#             date  year  month  week  dayofweek  day  hour  minute  quarter
# 339   2021-01-02  2021      1    53          5    2    18      27        1
# 340   2021-01-02  2021      1    53          5    2    18      27        1
# 341   2021-01-02  2021      1    53          5    2    18      28        1
# 342   2021-01-02  2021      1    53          5    2    18      28        1
# 343   2021-01-02  2021      1    53          5    2    18      28        1
# ...          ...   ...    ...   ...        ...  ...   ...     ...      ...
# 2443  2021-03-31  2021      3    13          2   31    14      33        1
# 2444  2021-03-31  2021      3    13          2   31    14      33        1
# 2445  2021-03-31  2021      3    13          2   31    14      34        1
# 2446  2021-03-31  2021      3    13          2   31    14      34        1
# 2447  2021-03-31  2021      3    13          2   31    14      37        1
#
# [2109 rows x 16 columns]

# %%
get_total_duration_by_(my_data,'month')
# Out:
#     month    minplayed
# 0       1  1804.386533
# 1       2  1536.882467
# 2       3  1929.805183
# 3       4   905.068533
# 4       5  1588.499917
# 5       6   980.355683
# 6       7  1079.875650
# 7       8  1217.961767
# 8       9  1706.807517
# 9      10  1537.396183
# 10     11  1646.570067
# 11     12  1419.990900

# %%
get_total_duration_by_(my_data,['day','month','year'])
# Out:
#      day  month  year   minplayed
# 0      1      4  2021   17.869217
# 1      1      5  2021   21.284900
# 2      1      6  2021   12.584233
# 3      1      7  2021   17.264567
# 4      1      9  2021  157.710167
# ..   ...    ...   ...         ...
# 220   31      1  2021   86.860300
# 221   31      3  2021   14.789967
# 222   31      7  2021   34.475533
# 223   31      8  2021   51.184217
# 224   31     12  2020  148.293783
#
# [225 rows x 4 columns]

# %%
get_moy_duration_by_(my_data,'dayofweek')
# Out:
#    dayofweek    amount
# 2          2  2.920696
# 5          5  2.749760
# 3          3  2.693855
# 6          6  2.497690
# 1          1  2.412191
# 4          4  2.302944
# 0          0  2.249490

# %%
get_total_duration_by_(my_data,'hour')
# Out:
#     hour    minplayed
# 0      0   243.450033
# 1      1   139.284050
# 2      2   194.985333
# 3      3   150.993067
# 4      4   153.539067
# 5      5   171.866283
# 6      6   334.186217
# 7      7   702.861650
# 8      8   674.803883
# 9      9   659.845950
# 10    10  1159.919333
# 11    11  1187.580333
# 12    12   856.952633
# 13    13   869.948650
# 14    14  1055.738817
# 15    15  1267.780383
# 16    16  1447.052350
# 17    17  1453.888567
# 18    18  1171.259017
# 19    19  1211.263117
# 20    20   841.240417
# 21    21   588.865383
# 22    22   515.833317
# 23    23   300.462550

# %%
#the most appearing artists
my_data \
    .groupby('artistname') \
    .sum()['msplayed'] \
    .reset_index() \
    .sort_values('msplayed', ascending=False) \
    .rename(columns={'msplayed': 'amount'}) \
    .head(10)
# Out:
#                artistname    amount
# 690  Si Maman M'avait Dit  40701480
# 386            Kanye West  27721115
# 627                  Rema  26459662
# 98                  Booba  24029590
# 382                Kalash  23386395
# 301      Hillsong Worship  23101648
# 814      William McDowell  22354874
# 818                WizKid  22245920
# 740                  Tayc  21014733
# 240           Fally Ipupa  18774919

# %%
#the most appearing artists
my_data \
    .groupby('trackname') \
    .sum()['msplayed'] \
    .reset_index() \
    .sort_values('msplayed', ascending=False) \
    .rename(columns={'msplayed': 'amount'}) \
    .head(10)
# Out:
#                               trackname    amount
# 722                           Ginger Me  10456353
# 1953  Withholding Nothing Medley (Live)   9253210
# 976                       King Of Kings   7131160
# 1929              What A Beautiful Name   6845253
# 324                           Bruxelles   6676250
# 1044                           Le temps   6557730
# 237                   Beamer (Bad Boys)   6026897
# 793                Here I Am To Worship   5807365
# 721            Ginger (feat. Burna Boy)   5798698
# 34                           4 croisees   5754335

# %%
#Top five artists from each year

counted_quarter_df = my_data \
    .assign(quarter_added=my_data.quarter) \
    .groupby(['artistname', 'quarter']) \
    .sum()['msplayed'] \
    .reset_index() \
    .sort_values('msplayed', ascending=False)

in_top_5_quarter_artist = counted_quarter_df \
    .groupby('quarter') \
    .head(5) \
    .artistname \
    .unique()


counted_quarter_df \
    [counted_quarter_df.artistname.isin(in_top_5_quarter_artist)] \
    .pivot('artistname', 'quarter', 'msplayed') \
    .fillna(0) \
    .style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col0{
#             background-color:  #84b0d3;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col1{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col2,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row1_col2,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row13_col0{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col3,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row3_col0,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row3_col3,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row7_col0,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row8_col2,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row8_col3,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row9_col0,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row9_col1,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row11_col0,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row11_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row1_col0,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row6_col3,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row11_col1,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row11_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row1_col1{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row1_col3{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row2_col0{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row2_col1{
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row2_col2{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row2_col3{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row3_col1{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row3_col2{
#             background-color:  #81aed2;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row4_col0{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row4_col1{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row4_col2{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row4_col3{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row5_col0{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row5_col1{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row5_col2,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row6_col2{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row5_col3{
#             background-color:  #2c89bd;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row6_col0{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row6_col1,#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row8_col0{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row7_col1{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row7_col2{
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row7_col3{
#             background-color:  #78abd0;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row8_col1{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row9_col2{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row9_col3{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row10_col0{
#             background-color:  #034e7b;
#             color:  #f1f1f1;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row10_col1{
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row10_col2{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row10_col3{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row12_col0{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row12_col1{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row12_col2{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row12_col3{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row13_col1{
#             background-color:  #358fc0;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row13_col2{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row13_col3{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row14_col0{
#             background-color:  #1379b5;
#             color:  #f1f1f1;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row14_col1{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row14_col2{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row14_col3{
#             background-color:  #dedcec;
#             color:  #000000;
#         }</style><table id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552" ><thead>    <tr>        <th class="index_name level0" >quarter</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >4</th>    </tr>    <tr>        <th class="index_name level0" >artistname</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552level0_row0" class="row_heading level0 row0" >Beyoncé</th>
#                         <td id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col0" class="data row0 col0" >8075898.000000</td>
#                         <td id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col1" class="data row0 col1" >1702893.000000</td>
#                         <td id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col2" class="data row0 col2" >682714.000000</td>
#                         <td id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row0_col3" class="data row0 col3" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552level0_row1" class="row_heading level0 row1" >Booba</th>
#                         <td id="T_cc69e034_6e6c_11ec_8f7c_8c85903bc552row1_col0" class="data row1 col0" >17547819.000000</td>
#                         <td id="T_cc69e034_6e6c_11ec_

# %% [markdown]
# ## Features added

# %% [markdown]
# features = create_features_df(my_data)

# %% [markdown]
# features = features.fillna(0)

# %% [markdown]
# features.to_csv("data/features.csv")

# %%
features = pd.read_csv("data/features.csv")

# %%
features.describe()
# Out:
#        Unnamed: 0     followers   popularity  danceability       energy  \
# count      2097.0  2.042000e+03  2042.000000   1937.000000  1937.000000
# mean          0.0  4.927891e+06    65.482860      0.684912     0.641732
# std           0.0  1.191435e+07    18.373952      0.151844     0.163726
# min           0.0  0.000000e+00     0.000000      0.000000     0.005420
# 25%           0.0  1.238178e+05    56.000000      0.591000     0.543000
# 50%           0.0  5.501190e+05    67.000000      0.713000     0.655000
# 75%           0.0  2.935515e+06    78.000000      0.795000     0.752000
# max           0.0  9.049773e+07    99.000000      0.976000     1.000000
#
#           loudness  speechiness  instrumentalness     liveness      valence  \
# count  1937.000000  1937.000000       1937.000000  1937.000000  1937.000000
# mean     -6.924622     0.143672          0.018214     0.163868     0.552328
# std       2.880102     0.124184          0.097983     0.133691     0.231020
# min     -37.841000     0.000000          0.000000     0.025600     0.000000
# 25%      -8.057000     0.049900          0.000000     0.093100     0.380000
# 50%      -6.544000     0.095600          0.000001     0.114000     0.561000
# 75%      -5.192000     0.205000          0.000123     0.179000     0.735000
# max      -0.510000     0.952000          0.934000     0.993000     0.981000
#
#              tempo    duration_ms
# count  1937.000000    1937.000000
# mean    118.969942  211479.327310
# std      29.296141   60863.085145
# min       0.000000   10760.000000
# 25%      98.286000  178147.000000
# 50%     114.938000  201333.000000
# 75%     136.083000  230867.000000
# max     235.927000  801160.000000

# %%
features
# Out:
#       Unnamed: 0        artistname  followers  \
# 0              0                ND  2501603.0
# 1              0             Ninho  5403852.0
# 2              0               Jul  4209659.0
# 3              0  Hillsong Worship  3570188.0
# 4              0             Hamza   599593.0
# ...          ...               ...        ...
# 2092           0          Singuila   185008.0
# 2093           0          Singuila   185008.0
# 2094           0          Singuila   185008.0
# 2095           0          Singuila   185008.0
# 2096           0          Singuila   185008.0
#
#                                                  genres  popularity  \
# 0            ['contemporary country', 'country', 'pop']        79.0
# 1                     ['french hip hop', 'pop urbaine']        87.0
# 2     ['alt z', 'dance pop', 'electropop', 'pop', 'p...        81.0
# 3     ['ccm', 'christian music', 'world worship', 'w...        77.0
# 4     ['belgian hip hop', 'french hip hop', 'pop urb...        71.0
# ...                                                 ...         ...
# 2092  ['azontobeats', 'francoton', 'french pop', 'po...        49.0
# 2093  ['azontobeats', 'francoton', 'french pop', 'po...        49.0
# 2094  ['azontobeats', 'francoton', 'french pop', 'po...        49.0
# 2095  ['azontobeats', 'francoton', 'french pop', 'po...        49.0
# 2096  ['azontobeats', 'francoton', 'french pop', 'po...        49.0
#
#      artistType                trackname  danceability  energy  loudness  \
# 0        artist                    Rodeo         0.724   0.822    -6.231
# 1        artist        La vie qu'on mène         0.800   0.756    -4.400
# 2        artist                   Tel Me         0.447   0.526    -8.064
# 3        artist    What A Beautiful Name         0.424   0.506    -5.877
# 4        artist  God Bless (feat. Damso)         0.861   0.572    -9.980
# ...         ...                      ...           ...     ...       ...
# 2092     artist            Ma conscience         0.655   0.721    -6.526
# 2093     artist              L'Imposteur           NaN     NaN       NaN
# 2094     artist           Comme personne         0.874   0.458    -8.384
# 2095     artist           Elle me saoûle         0.883   0.447    -9.186
# 2096     artist    L'amour ne suffit pas           NaN     NaN       NaN
#
#       speechiness  instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.0363          0.000000    0.0819    0.854  126.817     120049.0
# 1          0.0367          0.000002    0.1110    0.456  113.204     193444.0
# 2          0.0299          0.000000    0.1200    0.137   79.657     239640.0
# 3          0.0284          0.000000    0.1100    0.138  135.902     238200.0
# 4          0.1160          0.000751    0.0639    0.232   82.510     161743.0
# ...           ...               ...       ...      ...      ...          ...
# 2092       0.1680          0.000000    0.3670    0.689  165.942     221213.0
# 2093          NaN               NaN       NaN      NaN      NaN          NaN
# 2094       0.0863          0.000008    0.2460    0.803  133.899     251987.0
# 2095       0.0497          0.000333    0.0544    0.967  124.013     265707.0
# 2096          NaN               NaN       NaN      NaN      NaN          NaN
#
# [2097 rows x 16 columns]

# %%
get_list_features_by_track(my_data,features)
# Out:
#                  endtime artistname_x                         trackname  \
# 0    2020-12-04 18:21:00         GIMS                              YOLO
# 1    2020-12-05 00:01:00     Ya Levis                           Lokesha
# 2    2020-12-05 15:53:00         Tayc  African Sugar (avec Tiwa Savage)
# 3    2020-12-05 15:53:00    Axel Tony                              Miel
# 4    2020-12-06 13:22:00    Burna Boy                     African Giant
# ...                  ...          ...                               ...
# 7123 2021-12-05 17:25:00        Ninho                           No Life
# 7124 2021-12-05 17:28:00        Ninho                             RER D
# 7125 2021-12-05 17:29:00        Ninho                               YSL
# 7126 2021-12-05 17:29:00        Ninho                             Aïcha
# 7127 2021-12-05 17:29:00        Ninho                             Aïcha
#
#       msplayed               duration  minplayed               starttime  \
# 0        62314 0 days 00:01:02.314000   1.038567 2020-12-04 18:19:57.686
# 1       175885 0 days 00:02:55.885000   2.931417 2020-12-04 23:58:04.115
# 2         2304 0 days 00:00:02.304000   0.038400 2020-12-05 15:52:57.696
# 3         2538 0 days 00:00:02.538000   0.042300 2020-12-05 15:52:57.462
# 4         6997 0 days 00:00:06.997000   0.116617 2020-12-06 13:21:53.003
# ...        ...                    ...        ...                     ...
# 7123    108566 0 days 00:01:48.566000   1.809433 2021-12-05 17:23:11.434
# 7124    223101 0 days 00:03:43.101000   3.718350 2021-12-05 17:24:16.899
# 7125     15874 0 days 00:00:15.874000   0.264567 2021-12-05 17:28:44.126
# 7126     33024 0 days 00:00:33.024000   0.550400 2021-12-05 17:28:26.976
# 7127     33024 0 days 00:00:33.024000   0.550400 2021-12-05 17:28:26.976
#
#             date  year  month  ...  artistType  danceability  energy  \
# 0     2020-12-04  2020     12  ...      artist         0.756   0.720
# 1     2020-12-04  2020     12  ...      artist         0.661   0.562
# 2     2020-12-05  2020     12  ...      artist         0.000   0.000
# 3     2020-12-05  2020     12  ...      artist         0.596   0.662
# 4     2020-12-06  2020     12  ...      artist         0.570   0.648
# ...          ...   ...    ...  ...         ...           ...     ...
# 7123  2021-12-05  2021     12  ...      artist         0.506   0.553
# 7124  2021-12-05  2021     12  ...      artist         0.632   0.720
# 7125  2021-12-05  2021     12  ...      artist         0.712   0.801
# 7126  2021-12-05  2021     12  ...      artist         0.417   0.505
# 7127  2021-12-05  2021     12  ...      artist         0.843   0.622
#
#       loudness  speechiness  instrumentalness  liveness valence    tempo  \
# 0       -7.587       0.0627          0.000597     0.163   0.775   91.463
# 1       -6.907       0.1760          0.000014     0.152   0.739   87.910
# 2        0.000       0.0000          0.000000     0.000   0.000    0.000
# 3       -9.055       0.0451          0.000014     0.132   0.431  153.908
# 4       -6.694       0.3180          0.000081     0.568   0.564   90.503
# ...        ...          ...               ...       ...     ...      ...
# 7123    -7.751       0.3850          0.000000     0.122   0.329  173.603
# 7124    -7.163       0.3450          0.000050     0.303   0.165  183.003
# 7125    -6.384       0.3310          0.000000     0.227   0.281  121.024
# 7126    -6.479       0.1650          0.000000     0.106   0.767  183.976
# 7127    -6.565       0.1360          0.000029     0.121   0.442   98.079
#
#      duration_ms
# 0       197807.0
# 1       188960.0
# 2            0.0
# 3       213368.0
# 4       184761.0
# ...          ...
# 7123    237459.0
# 7124    223101.0
# 7125    218596.0
# 7126    200870.0
# 7127    219315.0
#
# [7128 rows x 31 columns]

# %%
tracks_with_features_df = my_data.merge(features, on=['artistname','trackname'], how='left')

# %%
tracks_with_features_df
# Out:
#                  endtime artistname                         trackname  \
# 0    2020-12-04 18:21:00       GIMS                              YOLO
# 1    2020-12-05 00:01:00   Ya Levis                           Lokesha
# 2    2020-12-05 15:53:00       Tayc  African Sugar (avec Tiwa Savage)
# 3    2020-12-05 15:53:00  Axel Tony                              Miel
# 4    2020-12-06 13:22:00  Burna Boy                     African Giant
# ...                  ...        ...                               ...
# 6802 2021-12-05 17:25:00      Ninho                           No Life
# 6803 2021-12-05 17:25:00      Ninho                           No Life
# 6804 2021-12-05 17:28:00      Ninho                             RER D
# 6805 2021-12-05 17:29:00      Ninho                               YSL
# 6806 2021-12-05 17:29:00      Ninho                             Aïcha
#
#       msplayed               duration  minplayed               starttime  \
# 0        62314 0 days 00:01:02.314000   1.038567 2020-12-04 18:19:57.686
# 1       175885 0 days 00:02:55.885000   2.931417 2020-12-04 23:58:04.115
# 2         2304 0 days 00:00:02.304000   0.038400 2020-12-05 15:52:57.696
# 3         2538 0 days 00:00:02.538000   0.042300 2020-12-05 15:52:57.462
# 4         6997 0 days 00:00:06.997000   0.116617 2020-12-06 13:21:53.003
# ...        ...                    ...        ...                     ...
# 6802      4522 0 days 00:00:04.522000   0.075367 2021-12-05 17:24:55.478
# 6803    108566 0 days 00:01:48.566000   1.809433 2021-12-05 17:23:11.434
# 6804    223101 0 days 00:03:43.101000   3.718350 2021-12-05 17:24:16.899
# 6805     15874 0 days 00:00:15.874000   0.264567 2021-12-05 17:28:44.126
# 6806     33024 0 days 00:00:33.024000   0.550400 2021-12-05 17:28:26.976
#
#             date  year  month  ...  artistType  danceability  energy  \
# 0     2020-12-04  2020     12  ...      artist         0.756   0.720
# 1     2020-12-04  2020     12  ...      artist         0.661   0.562
# 2     2020-12-05  2020     12  ...      artist           NaN     NaN
# 3     2020-12-05  2020     12  ...      artist         0.596   0.662
# 4     2020-12-06  2020     12  ...      artist         0.570   0.648
# ...          ...   ...    ...  ...         ...           ...     ...
# 6802  2021-12-05  2021     12  ...      artist         0.506   0.553
# 6803  2021-12-05  2021     12  ...      artist         0.506   0.553
# 6804  2021-12-05  2021     12  ...      artist         0.632   0.720
# 6805  2021-12-05  2021     12  ...      artist         0.712   0.801
# 6806  2021-12-05  2021     12  ...      artist         0.843   0.622
#
#       loudness  speechiness  instrumentalness  liveness valence    tempo  \
# 0       -7.587       0.0627          0.000597     0.163   0.775   91.463
# 1       -6.907       0.1760          0.000014     0.152   0.739   87.910
# 2          NaN          NaN               NaN       NaN     NaN      NaN
# 3       -9.055       0.0451          0.000014     0.132   0.431  153.908
# 4       -6.694       0.3180          0.000081     0.568   0.564   90.503
# ...        ...          ...               ...       ...     ...      ...
# 6802    -7.751       0.3850          0.000000     0.122   0.329  173.603
# 6803    -7.751       0.3850          0.000000     0.122   0.329  173.603
# 6804    -7.163       0.3450          0.000050     0.303   0.165  183.003
# 6805    -6.384       0.3310          0.000000     0.227   0.281  121.024
# 6806    -6.565       0.1360          0.000029     0.121   0.442   98.079
#
#      duration_ms
# 0       197807.0
# 1       188960.0
# 2            NaN
# 3       213368.0
# 4       184761.0
# ...          ...
# 6802    237459.0
# 6803    237459.0
# 6804    223101.0
# 6805    218596.0
# 6806    219315.0
#
# [6807 rows x 29 columns]

# %%
def get_top_max_of(df,feature):
    return df.sort_values(by=feature, ascending=False).head(6)

def get_top_min_of(df,feature):
    return df.sort_values(by=feature, ascending=True).head(6)

# %%
get_top_min_of(features,'valence').trackname
# Out:
# 882                         SI Maman M'avait Dit - Junior
# 1128    4. Les yeux dans les yeux - Avec Jean-Pascal Z...
# 714         Listen (From the Motion Picture "Dreamgirls")
# 718     6 - Connexions intimes (Intimate connections) ...
# 1482                           Loup garou (feat. Sofiane)
# 720     11 - La liberté : le courage d'être soi-même /...
# Name: trackname, dtype: object

# %%
new_features = features.drop(['Unnamed: 0','followers','genres','popularity','duration_ms','tempo','liveness','instrumentalness'],axis=1)



# Loudness feature is from -60db to 0 so we will normalise this column between 0 and 1
# Tempo feature is in BPM so we will scale between 0 and 1 too
from sklearn import preprocessing

loudness = new_features[['loudness']].values
min_max_scaler = preprocessing.MinMaxScaler()
loudness_scaled = min_max_scaler.fit_transform(loudness)
new_features['loudness'] = pd.DataFrame(loudness_scaled)

new_features.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'danceability'}>,
#         <AxesSubplot:title={'center':'energy'}>],
#        [<AxesSubplot:title={'center':'loudness'}>,
#         <AxesSubplot:title={'center':'speechiness'}>],
#        [<AxesSubplot:title={'center':'valence'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# remove song names, artist and id before clustering
songs_features = new_features.copy()
songs_features = songs_features.drop(['artistType','artistname','trackname'],axis=1)

# %%
songs_features
# Out:
#       danceability  energy  loudness  speechiness  valence
# 0            0.756   0.720  0.799503       0.0627    0.775
# 1            0.661   0.562  0.817473       0.1760    0.739
# 2            0.000   0.000  1.000000       0.0000    0.000
# 3            0.596   0.662  0.760709       0.0451    0.431
# 4            0.570   0.648  0.823102       0.3180    0.564
# ...            ...     ...       ...          ...      ...
# 2051         0.696   0.776  0.839698       0.3670    0.374
# 2052         0.506   0.553  0.795169       0.3850    0.329
# 2053         0.632   0.720  0.810708       0.3450    0.165
# 2054         0.712   0.801  0.831294       0.3310    0.281
# 2055         0.843   0.622  0.826511       0.1360    0.442
#
# [2056 rows x 5 columns]

# %%
from sklearn.cluster import KMeans

Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(songs_features)
    Sum_of_squared_distances.append(km.inertia_)

# %%
from sklearn.metrics import silhouette_score
for n_clusters in range(2,15):
    clusterer = KMeans (n_clusters=n_clusters)
    preds = clusterer.fit_predict(songs_features)
    centers = clusterer.cluster_centers_

    score = silhouette_score (songs_features, preds, metric='euclidean')
    print ("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.5730769037318545)
# For n_clusters = 3, silhouette score is 0.3603822178861892)
# For n_clusters = 4, silhouette score is 0.2919430957471456)
# For n_clusters = 5, silhouette score is 0.2797614494402451)
# For n_clusters = 6, silhouette score is 0.2636617383816356)
# For n_clusters = 7, silhouette score is 0.26775901365008886)
# For n_clusters = 8, silhouette score is 0.26328455966525505)
# For n_clusters = 9, silhouette score is 0.26172016766319095)
# For n_clusters = 10, silhouette score is 0.2708507834812681)
# For n_clusters = 11, silhouette score is 0.26626199106051696)
# For n_clusters = 12, silhouette score is 0.267973318397482)
# For n_clusters = 13, silhouette score is 0.25771958802234013)
# For n_clusters = 14, silhouette score is 0.2589820152106823)

# %%
plt.plot(K, Sum_of_squared_distances, 'gx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(songs_features)
# Out:
# KMeans(n_clusters=4)

# %%
# PCA to reduce our data to 2 dimensions for visualisation
from sklearn.decomposition import PCA
y_kmeans = kmeans.predict(songs_features)
pca = PCA(n_components=2)
principal_components = pca.fit_transform(songs_features)

# %%
pc = pd.DataFrame(principal_components)
pc['label'] = y_kmeans
pc.columns = ['x', 'y','label']

#plot data with seaborn
cluster = sns.lmplot(data=pc, x='x', y='y', hue='label', 
                   fit_reg=False, legend=True, legend_out=True)
